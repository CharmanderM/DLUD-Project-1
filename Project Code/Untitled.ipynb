# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

DATADIR = "/Users/yiboma/Desktop/project_1_data_set_team_quad"
CATEGORIES = ["motherbaby","pornstar"]

for category in CATEGORIES:
    path = os.path.join(DATADIR, category) #path to motherbaby and pornstar dir
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        # img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(img_array, cmap="gray")
        plt.show()
        break
    break

# %%
print(img_array.shape)
# Out:
# (183, 275)

# %%
IMG_SIZE = 100

new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array, cmap = 'gray')
plt.show()

# %%
training_data = []

def creat_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category) #path to motherbaby and pornstar dir
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                training_data.append([new_array, class_num])
            except Exception as e:
                pass
training_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-f5760e9c0b12> in <module>
#      12             except Exception as e:
#      13                 pass
# ---> 14 training_data()
#
# TypeError: 'list' object is not callable

# %%
print(len(training_data))
# Out:
# 0

# %%
import random

random.shuffle(training_data)

# %%
for sample in training_data:
